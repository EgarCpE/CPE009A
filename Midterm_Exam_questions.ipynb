# %% [markdown]
# <a href="https://colab.research.google.com/github/EgarCpE/CPE009A/blob/main/Midterm_Exam_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 23. Nested loop for
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
i = 1
for i in range(1):
  print('*')
  if i in range(2):
    print('**')
    if i in range(3):
      print('***')
      if i in range(4):
        print('****')
        if i in range(5):
          print('*****')
        if i in range(4):
          print('****')
        if i in range(3):
            print('***')
      if i in range(2):
            print('**')
    if i in range(1):
          print('*')
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# 24.Write a function that checks if a string of parentheses (), brackets [], and braces {} is balanced.
#
# Examples:
#
#     "({[]})" → True
#
#     "([)]" → False
#
#     "((()))" → True
#
#     "({)}" → False

# %%
str("({[]})") == True
str("([))") == False
str("((()))") == True
str("({)}") == False


print(input("Enter code: "))

if input == "({[]})":
  print(True)
  if input == "([)]":
    print(False)
    if input == "((()))":
      print(True)
      if input == "({)}":
        print(False)
# Out:
# Enter code: "({[]})"
# "({[]})"
