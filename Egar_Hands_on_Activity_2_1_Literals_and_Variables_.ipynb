# %% [markdown]
# <a href="https://colab.research.google.com/github/EgarCpE/CPE009A/blob/main/Egar_Hands_on_Activity_2_1_Literals_and_Variables_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title:</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed:** 1/15/2026 |
# | **Section**:CPE12S2  | **Date Submitted:** |
# | **Student Name**: Jarel Dave R. Egar  | **Instructor's Name:** Ma'am. Sayo, Maria Rizette|
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   List item
# 2.   List item
#
# **Intended Learning Outcome:**
#
# 1.   List item
# 2.   List item
#
# **Discussion:**
#
# (put your discussions here)
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

name = input("Enter your name: ")
course = input("Enter your course: ")
section = input("Enter your section: ")
year = input("Enter your year: ")

print()
print ("Prelim")

Prelim_HOA = float(input("Enter Hands-on Activity Prelim grade: "))
Prelim_QUIZ = float(input("Enter Prelim Quiz grade: "))
Prelim_AS = float(input("Enter Prelim Assignment grade: "))
Prelim_CS = Prelim_HOA*0.5 + Prelim_QUIZ*.3 + Prelim_AS*.2
print("Prelim CS is: ", Prelim_CS)
Prelim_EX = float(input("Enter Prelim Exam grade: "))
PrelimGrade = Prelim_EX*.5 + Prelim_CS*.5
print("Prelim Grade is: ", "%.2f" % PrelimGrade)

print()
print("Midterm Grades")

Midterm_HOA = float(input("Enter Hands-on Activity Midterm grade: "))
Midterm_QUIZ = float(input("Enter midterm Quiz grade: "))
Midterm_AS = float(input("Enter midtermm Assignment grade: "))
Midterm_CS = Midterm_HOA*.5 + Midterm_QUIZ*.3 + Midterm_AS*.2
print("Midterm CS is: ", Midterm_CS)
Midterm_EX = float(input("Enter Midterm Exam grade: "))
MidtermGrade = (PrelimGrade*(1/3)) + (2/3)*(Midterm_EX*.5 + Midterm_CS*.5)
print("Midermm Grade is: ", "%.2f" % MidtermGrade )

print()
print("Finals")
Finals_HOA = float(input("Enter Hands-on Activity Finals grade: "))
Finals_QUIZ = float(input("Enter midterm Quiz grade: "))
Finals_AS = float(input("Enter midtermm Assignment grade: "))
Finals_CS = Midterm_HOA*.5 + Midterm_QUIZ*.3 + Midterm_AS*.2
print("Finals CS is: ", Finals_CS)
Finals_EX = float(input("Enter Midterm Exam grade: "))
FinalsGrade = (MidtermGrade*(1/3)) + (2/3)*(Finals_EX*.5 + Finals_CS*.5)
print("Finals Grade is: ", "%.2f" % FinalsGrade )
# Out:
# Enter your name:
# Enter your course:
# Enter your year:
# Prelim
# Enter Hands-on Activity Prelim grade: 100
# Enter Prelim Quiz grade: 1000
# Enter Prelim Assignment grade: 1000
# Prelim CS is:  550.0
# Enter Prelim Exam grade: 1000
# Prelim Grade is:  775.00
#
# Midterm Grades
# Enter Hands-on Activity Midterm grade: 000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-643048687.py in <cell line: 0>()
#      20
#      21 Midterm_HOA = float(input("Enter Hands-on Activity Midterm grade: "))
# ---> 22 Midterm_QUIZ = float(input("Enter midterm Quiz grade: "))
#      23 Midterm_AS = float(input("Enter midtermm Assignment grade: "))
#      24 Midterm_CS = Midterm_HOA*.5 + Midterm_QUIZ*.3 + Midterm_AS*.2
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %% [markdown]
# 1**Supplementary Activity**:
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)
