# %% [markdown]
# <a href="https://colab.research.google.com/github/EgarCpE/CPE009A/blob/main/Egar_Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If Statement

# %%
a = 12
b = 100
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 12
b = 100
if b<a:
  print("b is greater than a")

# %% [markdown]
# Elif Statement

# %%
a = 12
b = 12
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# Else Statement

# %%
a = 200
b = 33
if b>a:
  print("b is greater than a")
elif a ++ b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a and b are equal

# %% [markdown]
# Short hand if Statement

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If..Else Statement

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# And-both conditions are true

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# Or-at least one of the conditions is true

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the condiotions is True")
# Out:
# At least one of the condiotions is True

# %% [markdown]
# Nested If

# %%
x = 41
if x>10:
  print("above ten")
  if x>20:
    print("and also above 20")
    if x>30:
      print("and also above 30")
      if x>40:
        print("and also above 40")
      else:
        print("but not above 40")
    else:
        print("but not above 30")
  else:
    print("but not above 20")
else:
  print("but not above 10")
# Out:
# above ten
# and also above 20
# and also above 30
# and also above 40

# %%
print ("Enter Grade:")
grade = int(input())


if grade >= 75:
  print ("Passed")
elif grade >= 74:
  print ("remidial")
  if grade >= 74:
    print ("failed")
else:
  print ("failed")
if grade <= 1:
  print ("invalid grade")
# Out:
# Enter Grade:
