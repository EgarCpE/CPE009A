# %% [markdown]
# <a href="https://colab.research.google.com/github/EgarCpE/CPE009A/blob/main/Phyton_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 5 > 2:
  print("Gusto ko na agad umuwi")
# Out:
# Gusto ko na agad umuwi

# %%
#this is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %%
#This is my Name
print("Tensionado, nagulat din ako nung malaman, na hindi lang pala ako yung nang hinayang, nung nag away tayo non at na tuluyan.")
# Out:
# Tensionado, nagulat din ako nung malaman, na hindi lang pala ako yung nang hinayang, nung nag away tayo non at na tuluyan.

# %%
x = 1
a, b = 0,-1
a,b,c = 0,-1,2
b = "Sally" #this is a type of string

# %%
print (b)
# Out:
# Sally

# %%
print (x)
# Out:
# 1

# %%
b="sally" #this is a type of string
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %%
b="sally" #this is a type of string
print(b)
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# sally
# 4
# 4.0

# %%
x = 5
y = "John"

print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = 5
y = "John"
z = 'a'

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
y = "John"
y = 'John'

# %%
print(y)
print(y)
# Out:
# John
# John

# %%
a = 4
A = "Sally"

# %%
print(a)
print(A)
# Out:
# 4
# Sally

# %%
x,y,z = "one", "two", "three"
print(x,y,z)
# Out:
# one two three

# %%
x,y,z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %%
x = "enjoying"
print("Phyton programming is" + x)
# Out:
# Phyton programming isenjoying

# %%
x = " enjoying"
print("Phyton programming is" + x)
# Out:
# Phyton programming is enjoying

# %%
x = "Phyton is "
y = "Enjoying"
z = x+y
print(z)
# Out:
# Phyton is Enjoying

# %%
x = 5
y = 3
print(x+y)

x = 5
y = 3
sum = (x+y)
sum
# Out:
# 8
# 8

# %%
x = 5
y = 3
print(x+y)

x = 5
y = 3
sum = (x+y)
sum

x = 5
y = 3
print(x-y)

x = 5
y = 3
subtract = (x-y)
subtract

x = 5
y = 3
print(x*y)

x = 5
y = 3
multiply = (x*y)
multiply

x = 5
y = 3
print(x/y)

x = 5
y = 3
divide = (x/y)
divide

x = 5
y = 3
print(x&y)

x = 5
y = 3
modulo = (x%y)
modulo

x = 5
y = 3
print(x**y)

x = 5
y = 3
exponation = (x**y)
exponation

x = 5
y = 3
print(x//y)

x = 5
y = 3
floorDivision = (x//y)
floorDivision
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 125
# 1
# 1

# %%
x + =3
print (x)
# Out:
#   File "/tmp/ipython-input-4109037248.py", line 1
#     x + =3
#         ^
# SyntaxError: invalid syntax

# %%
s = 1

# %%
s +=3
print(s)
# Out:
# 4

# %%
s -=3
print(s)
s *=3
print(s)
s //=3
print(s)
s %=3
print(s)
s //=3
print(s)
s **=3
print(s)
s = int(s)
s &=3
print(s)
s |=3
print(s)
s ^=3
print(s)
s >>=3
print(s)
s <<=3
print(s)
# Out:
# -3.0
# -9.0
# -3.0
# 0.0
# 0.0
# 0.0
# 0
# 3
# 0
# 0
# 0

# %%
s -=3
print(s)
s *=3
print(s)
s /=3
print(s)
s %=3
print(s)
s //=3
print(s)
s **=3
print(s)
s &=3
print(s)
s |=3s
print(s)
s ^=3
print(s)
s >>=3
print(s)
s <<=3
print(s)
# Out:
#   File "/tmp/ipython-input-3954452994.py", line 15
#     s |=3s
#         ^
# SyntaxError: invalid decimal literal

# %%
t = 1
u = 2

# %%
print (t==u)
print (t!=u)
print (t>u)
print (t<u)
print (t>=u)
print (t<=u)
# Out:
# False
# True
# False
# True
# False
# True

# %%
x = 10
(x < 4 and x <10)
# Out:
# False

# %%
x = 10
(x < 5 or x <4)
# Out:
# False

# %%
x = 10
not(x < 5 and x <10)
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
v = 2

# %%
v << 2
# Out:
# 8

# %%
1&2
# Out:
# 0

# %%
15&15
# Out:
# 15
